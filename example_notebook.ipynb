# %%
import pandas as pd

def convert_dtype(x):
    if not x:
        return ''
    try:
        return str(x)   
    except:        
        return ''

df = pd.read_csv('download.csv',converters={'Sustainable Development Goals': convert_dtype})

df.head()
# Out:
#   Issuance Date Sustainable Development Goals Vintage Start Vintage End    ID  \
# 0    07/10/2022                                  01/01/2021  31/10/2021  1671
# 1    07/10/2022                                  01/01/2021  31/10/2021  1523
# 2    06/10/2022                                  01/01/2017  31/12/2017   902
# 3    06/10/2022                                  01/01/2012  31/12/2012    82
# 4    06/10/2022                                  01/01/2021  31/03/2021   428
#
#                                                 Name Country/Area  \
# 0  Wind based power generation by Panama Wind Ene...        India
# 1  Wind Based Power Generation by Panama Wind Ene...        India
# 2                               KARIBA REDD+ PROJECT     Zimbabwe
# 3  Wastewater Treatment with Biogas Production (U...     Thailand
# 4  Chol Charoen Group Wastewater Treatment with B...     Thailand
#
#                                         Project Type  \
# 0  Energy industries (renewable/non-renewable sou...
# 1  Energy industries (renewable/non-renewable sou...
# 2            Agriculture Forestry and Other Land Use
# 3                        Waste handling and disposal
# 4  Energy industries (renewable/non-renewable sou...
#
#                       Methodology Total Vintage Quantity Quantity Issued  \
# 0                         ACM0002                 66,398          66,398
# 1                         ACM0002                 83,668          83,668
# 2                          VM0009              3,623,622          80,000
# 3                         ACM0014                121,934           7,010
# 4  AMS-I.C.; AMS-I.D.; AMS-III.H.                 16,599             600
#
#                                        Serial Number  \
# 0  13834-529253537-529319934-VCS-VCU-814-VER-IN-1...
# 1  13835-529319935-529403602-VCS-VCU-997-VER-IN-1...
# 2  13823-529087449-529167448-VCS-VCU-352-VER-ZW-1...
# 3  13824-529167449-529174458-VCS-VCU-291-VER-TH-1...
# 4  13825-529174459-529175058-VCS-VCU-291-VER-TH-1...
#
#                            Additional Certifications  \
# 0                                                NaN
# 1                                                NaN
# 2  CCB-Biodiversity Gold; CCB-Climate Gold; CCB-Gold
# 3                                                NaN
# 4                                                NaN
#
#   Retirement/Cancellation Date Retirement Beneficiary Retirement Reason  \
# 0                          NaN                    NaN               NaN
# 1                          NaN                    NaN               NaN
# 2                          NaN                    NaN               NaN
# 3                          NaN                    NaN               NaN
# 4                          NaN                    NaN               NaN
#
#   Retirement Details
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df.to_json('download.json')

# %%
kenya_data = df[df['Country/Area'] == 'Kenya']
print(kenya_data.head())
print(kenya_data.shape)
# Out:
#      Issuance Date Sustainable Development Goals Vintage Start Vintage End  \
# 25      03/10/2022                                  01/01/2015  31/12/2016
# 531     11/07/2022                                  01/01/2016  31/12/2016
# 1123    16/05/2022                                  26/04/2019  31/12/2019
# 1124    16/05/2022                                  26/04/2019  31/12/2019
# 1125    16/05/2022                                  26/04/2019  31/12/2019
#
#         ID                                     Name Country/Area  \
# 25    1347              KSAIL Bagasse Power Project        Kenya
# 531   1408               Chyulu Hills REDD+ Project        Kenya
# 1123  1918  Paradigm Kenya Clean Cookstoves Project        Kenya
# 1124  1918  Paradigm Kenya Clean Cookstoves Project        Kenya
# 1125  1918  Paradigm Kenya Clean Cookstoves Project        Kenya
#
#                                            Project Type Methodology  \
# 25    Energy industries (renewable/non-renewable sou...     ACM0006
# 531             Agriculture Forestry and Other Land Use      VM0009
# 1123                                      Energy demand   AMS-II.G.
# 1124                                      Energy demand   AMS-II.G.
# 1125                                      Energy demand   AMS-II.G.
#
#      Total Vintage Quantity Quantity Issued  \
# 25                    7,504           7,504
# 531                 617,707          46,627
# 1123                 43,613          20,000
# 1124                 43,613           5,000
# 1125                 43,613           8,449
#
#                                           Serial Number  \
# 25    13812-528585310-528592813-VCS-VCU-814-VER-KE-1...
# 531   13439-503088289-503134915-VCS-VCU-263-VER-KE-1...
# 1123  13082-470841436-470861435-VCS-VCU-814-VER-KE-3...
# 1124  13082-470861436-470866435-VCS-VCU-814-VER-KE-3...
# 1125  13082-470866436-470874884-VCS-VCU-814-VER-KE-3...
#
#                               Additional Certifications  \
# 25                                                  NaN
# 531   CCB-Biodiversity Gold; CCB-Climate Gold; CCB-C...
# 1123                                                NaN
# 1124                                                NaN
# 1125                                                NaN
#
#      Retirement/Cancellation Date Retirement Beneficiary Retirement Reason  \
# 25                            NaN                    NaN               NaN
# 531                           NaN                    NaN               NaN
# 1123                          NaN                    NaN               NaN
# 1124                          NaN                    NaN               NaN
# 1125                   18/05/2022                    NaN               NaN
#
#      Retirement Details
# 25                  NaN
# 531                 NaN
# 1123                NaN
# 1124                NaN
# 1125                NaN
# (7954, 17)
